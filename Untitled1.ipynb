# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreaOmodeo/colab/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas==1.1.0
# !pip install -Uqq fastai

# %%
# CLICK ME
from fastai.vision.all import *
path = untar_data(URLs.PETS)/'images'

# %%
def is_cat(x): return x[0].isupper()
dls = ImageDataLoaders.from_name_func(
        path, get_image_files(path), valid_pct=0.2, seed=42,    
        label_func=is_cat, item_tfms=Resize(224))

learn = cnn_learner(dls, resnet34, metrics=error_rate)
learn.fine_tune(6)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/hub/checkpoints/resnet34-333f7ec4.pth
# ...
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.173778</td>
#       <td>0.020974</td>
#       <td>0.006089</td>
#       <td>00:49</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.051542</td>
#       <td>0.017511</td>
#       <td>0.005413</td>
#       <td>00:52</td>
#     </tr>
#     <tr>
#       <td>1</td>
# ...

# %%
img = PILImage.create(dls.items[0])

# %%
img.to_thumb(256)
# Out:
# <PIL.Image.Image image mode=RGB size=256x148 at 0x7FD2BF5214E0>

# %%
path = untar_data(URLs.CAMVID_TINY)

dls = SegmentationDataLoaders.from_label_func(    
	path, bs=8, fnames = get_image_files(path/"images"),    
	label_func = lambda o: path/'labels'/f'{o.stem}_P{o.suffix}',    
	codes = np.loadtxt(path/'codes.txt', dtype=str)
)

learn = unet_learner(dls, resnet34)
learn.fine_tune(16)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.978277</td>
#       <td>2.308950</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.812720</td>
#       <td>1.519696</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.601666</td>
#       <td>1.337392</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.438776</td>
#       <td>1.162692</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.320825</td>
# ...

# %%
path
# Out:
# Path('/root/.fastai/data/camvid_tiny')

# %%
img = PILImage.create(dls.items[2])
img
# Out:
# PILImage mode=RGB size=128x96

# %%
learn.show_results(max_n=6, figsize=(7,8))

# %%
from fastai.text.all import *

dls = TextDataLoaders.from_folder(untar_data(URLs.IMDB), valid='test')

learn = text_classifier_learner(dls, AWD_LSTM, drop_mult=0.5, metrics=accuracy)

learn.fine_tune(4, 1e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.600462</td>
#       <td>0.397194</td>
#       <td>0.820040</td>
#       <td>03:42</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.307285</td>
#       <td>0.250381</td>
#       <td>0.899480</td>
#       <td>07:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.235364</td>
#       <td>0.206688</td>
#       <td>0.919240</td>
#       <td>07:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
# ...

# %%
learn.predict("I hate that boring movie!")
# Out:
# ('neg', tensor(0), tensor([0.9897, 0.0103]))

# %%
from fastai.tabular.all import *

path = untar_data(URLs.ADULT_SAMPLE)

dls = TabularDataLoaders.from_csv(path/'adult.csv', path=path, y_names="salary",    
                                  cat_names = ['workclass', 'education', 'marital-status', 'occupation',  'relationship', 'race'],    
                                  cont_names = ['age', 'fnlwgt', 'education-num'],    
                                  procs = [Categorify, FillMissing, Normalize])

learn = tabular_learner(dls, metrics=accuracy)

# %%
dls.dataset
# Out:
#             age  workclass    fnlwgt  ...  native-country  salary  education-num_na
# 14423 -1.510152          5 -0.482352  ...   United-States       0                 1
# 28530 -0.997103          5 -1.436685  ...   United-States       0                 1
# 17983  1.788019          1  1.988431  ...   United-States       0                 1
# 17036 -0.410761          7  1.592851  ...   United-States       0                 1
# 26670  0.615336          8 -1.264860  ...   United-States       1                 1
# ...         ...        ...       ...  ...             ...     ...               ...
# 8773   1.421556          5  0.418906  ...   United-States       0                 1
# 19312 -0.557347          5  1.911632  ...   United-States       0                 1
# 14513 -1.436859          1 -1.433416  ...   United-States       0                 1
# 10831 -0.850518          5 -0.536395  ...   United-States       0                 1
# ...

# %%
learn.fit_one_cycle(3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.371463</td>
#       <td>0.351183</td>
#       <td>0.835227</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.359991</td>
#       <td>0.342394</td>
#       <td>0.839220</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.345970</td>
#       <td>0.337613</td>
#       <td>0.846130</td>
#       <td>00:04</td>
#     </tr>
#   </tbody>
# </table>

# %%
from fastai.collab import *
path = untar_data(URLs.ML_SAMPLE)
dls = CollabDataLoaders.from_csv(path/'ratings.csv')
learn = collab_learner(dls, y_range=(0.5,5.5))
learn.fine_tune(10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.530373</td>
#       <td>1.365281</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.375983</td>
#       <td>1.304489</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.259791</td>
#       <td>1.124305</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.024021</td>
#       <td>0.835777</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.794746</td>
# ...
